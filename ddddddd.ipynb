# %% [markdown]
# <a href="https://colab.research.google.com/github/instone1031/114514/blob/main/ddddddd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (1, 19):
  for j in range(1, 19):
    print(f"{i}*{j}={i*j}")
# Out:
# 1*1=1
# 1*2=2
# 1*3=3
# 1*4=4
# 1*5=5
# 1*6=6
# 1*7=7
# 1*8=8
# 1*9=9
# 1*10=10
# 1*11=11
# 1*12=12
# 1*13=13
# 1*14=14
# 1*15=15
# 1*16=16
# 1*17=17
# 1*18=18
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20
# 2*11=22
# 2*12=24
# 2*13=26
# 2*14=28
# 2*15=30
# 2*16=32
# 2*17=34
# 2*18=36
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# 3*10=30
# 3*11=33
# 3*12=36
# 3*13=39
# 3*14=42
# 3*15=45
# 3*16=48
# 3*17=51
# 3*18=54
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 4*10=40
# 4*11=44
# 4*12=48
# 4*13=52
# 4*14=56
# 4*15=60
# 4*16=64
# 4*17=68
# 4*18=72
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
# 5*11=55
# 5*12=60
# 5*13=65
# 5*14=70
# 5*15=75
# 5*16=80
# 5*17=85
# 5*18=90
# 6*1=6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 6*7=42
# 6*8=48
# 6*9=54
# 6*10=60
# 6*11=66
# 6*12=72
# 6*13=78
# 6*14=84
# 6*15=90
# 6*16=96
# 6*17=102
# ...

# %%
x = int(input("처음 숫자를 입력하시오: "))
y = int(input("곱할 숫자를 입력하시오: "))

TT = x * y

print(TT)
# Out:
# 처음 숫자를 입력하시오: 15
# 곱할 숫자를 입력하시오: 15
# 225

# %%
import random
